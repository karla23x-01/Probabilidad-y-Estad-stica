# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Unidad5/2RegresionLineal_Correlacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadística
# ##Unidad 5
# ###Facilitador: José Gabriel Rodriguez Rivas
# ###Alumno: Karla María Fuentes González
# ### **2 Regresion Lineal y Correlacional**

# %%
from scipy.stats import pearsonr

# Datos de entrada
publicidad = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

# Calcular el coeficiente de correlación de Pearson
coeficiente_correlacion, p_valor = pearsonr(publicidad, ganancias)

print("Coeficiente de correlación de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlación de Pearson: 0.909090909090909
# Valor p: 0.012021036814425281
