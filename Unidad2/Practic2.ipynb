# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Unidad2/Practic2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadística
# ##Unidad 2
# ###Facilitador: José Gabriel Rodriguez Rivas
# ###Alumno: Karla María Fuentes González
# ### **Programa 2: Permutaciones**

# %%
import math as mt # Para utilziar factorial
from itertools import permutations
from itertools import product
import numpy as np

# %%
mt.factorial(7)
# Out:
# 5040

# %%
mt.factorial(4)
# Out:
# 24

# %%
5040 / 24
# Out:
# 210.0

# %%
nombres = ["a", "b", "с", "d","e","f","g"]
n = len(nombres)
r = 3 # ¿cómo agrupar?

Pr = mt.factorial(n) / (mt.factorial(n-r))

print("Existen ",Pr," posibles permutaciones sin repetición del total de ", n, "en grupos de ",r,"en",r)
print("Aquí las permutaciones")
permutaciones_nombres= list(permutations (nombres, r))
# Imprime las permutaciones
for permutacion in permutaciones_nombres:
     print(permutacion)
# Out:
# Existen  210.0  posibles permutaciones sin repetición del total de  7 en grupos de  3 en 3
# Aquí las permutaciones
# ('a', 'b', 'с')
# ('a', 'b', 'd')
# ('a', 'b', 'e')
# ('a', 'b', 'f')
# ('a', 'b', 'g')
# ('a', 'с', 'b')
# ('a', 'с', 'd')
# ('a', 'с', 'e')
# ('a', 'с', 'f')
# ('a', 'с', 'g')
# ('a', 'd', 'b')
# ('a', 'd', 'с')
# ('a', 'd', 'e')
# ('a', 'd', 'f')
# ('a', 'd', 'g')
# ('a', 'e', 'b')
# ('a', 'e', 'с')
# ('a', 'e', 'd')
# ('a', 'e', 'f')
# ('a', 'e', 'g')
# ('a', 'f', 'b')
# ('a', 'f', 'с')
# ('a', 'f', 'd')
# ('a', 'f', 'e')
# ('a', 'f', 'g')
# ('a', 'g', 'b')
# ('a', 'g', 'с')
# ('a', 'g', 'd')
# ('a', 'g', 'e')
# ('a', 'g', 'f')
# ('b', 'a', 'с')
# ('b', 'a', 'd')
# ('b', 'a', 'e')
# ('b', 'a', 'f')
# ('b', 'a', 'g')
# ('b', 'с', 'a')
# ('b', 'с', 'd')
# ('b', 'с', 'e')
# ('b', 'с', 'f')
# ('b', 'с', 'g')
# ('b', 'd', 'a')
# ('b', 'd', 'с')
# ('b', 'd', 'e')
# ('b', 'd', 'f')
# ('b', 'd', 'g')
# ('b', 'e', 'a')
# ('b', 'e', 'с')
# ('b', 'e', 'd')
# ('b', 'e', 'f')
# ...
