# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Pr%C3%A1ctica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##UNIDAD 1
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
# ###Alumno: FUENTES GONZÁLEZ KARLA MARÍA
# PROGRAMA 2: MAXIMO, MINIMO Y DISPERSION DE DATOS

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
Fabrica1 = []
for _ in range (100):
    numero_aleatorio = round(random.uniform(50,1000), 2)
    Fabrica1.append(numero_aleatorio)
print(Fabrica1)
# Out:
#   File "/tmp/ipython-input-1276780315.py", line 3
#     numero aleatorio = round (random. uniform (50,1000), 2)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
Fabrica2 = [1
for
_in range range(100) :
numero _aleatorio = round (random.uniform(50,1000), 2)
Fabrica2. append (numero _aleatorio)
print (Fabrica2)

# %%
maximo1 = max(Fabricaj)
minimo1 = min (Fabrica1)
rango1 = maximo1 - minimo1
medial = mean (Fabrica1)
medianal = median (Fabrica1)
moda1 = mode (Fabrica1)
desviacion estandar_ Fabrical - stdev(Fabrical)
print("Estadistica descriptiva de la Fabrica 1 \n*, Media =*
,media1,
"\n Medaiana =", mediana1, "\n Moda=*
,moda1, An Maximo="
,maximo1,
"\n Minimo =", minimo1, "\n Rango=*, rango1)
print ("Desviacion Estandar =", desviacion estandar_Fabrica1)
