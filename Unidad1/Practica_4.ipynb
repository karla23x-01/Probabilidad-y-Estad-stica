# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Unidad1/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##UNIDAD 1
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
# ###Alumno: FUENTES GONZÁLEZ KARLA MARÍA
# PROGRAMA 4: **Diagramas de cajas y bigotes**

# %%
import random

import matplotlib.pyplot as plt

from statistics import *

# %%
fabrica1 = []

for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)

print(fabrica1)
# Out:
# [86.77, 88.23, 98.31, 85.25, 73.56, 86.4, 64.13, 59.17, 91.49, 83.34, 88.53, 52.93, 89.33, 97.35, 85.16, 99.75, 85.82, 54.35, 54.93, 84.75, 91.5, 89.08, 64.66, 85.39, 70.29, 76.47, 71.51, 79.58, 70.17, 78.92, 50.56, 84.76, 64.88, 89.37, 70.96, 64.13, 62.87, 99.07, 83.27, 89.63, 60.34, 89.01, 94.2, 50.39, 78.46, 98.68, 61.03, 95.52, 64.99, 63.18, 65.51, 86.43, 69.5, 93.16, 73.81, 80.51, 81.85, 50.46, 50.04, 58.78, 74.99, 60.39, 75.85, 78.97, 65.07, 68.14, 99.78, 99.06, 58.56, 64.01, 56.94, 83.94, 63.77, 64.95, 82.24, 77.12, 73.47, 68.77, 53.82, 61.87, 61.66, 82.74, 53.8, 92.22, 77.14, 84.43, 60.3, 98.35, 65.14, 86.94, 87.24, 77.06, 61.33, 66.42, 93.36, 86.18, 75.11, 68.67, 84.41, 61.74]

# %%
fabrica2 = []

for i in range(100):
    numero_aleatorio = round(random.uniform(48, 93), 2)
    fabrica2.append(numero_aleatorio)

print(fabrica2)
# Out:
# [64.09, 75.58, 59.31, 55.27, 61.55, 76.46, 92.83, 68.73, 60.32, 65.88, 84.47, 70.8, 71.44, 82.13, 74.38, 52.87, 74.05, 79.79, 71.62, 89.39, 70.42, 89.48, 85.34, 61.54, 76.78, 56.24, 64.82, 57.14, 73.79, 68.47, 51.54, 71.9, 78.45, 64.32, 75.04, 80.17, 84.28, 52.98, 75.02, 84.41, 54.08, 58.62, 67.35, 70.35, 61.42, 70.92, 78.11, 60.43, 51.99, 85.88, 87.91, 86.9, 86.71, 64.43, 87.33, 64.08, 65.53, 69.93, 65.18, 49.17, 54.12, 61.26, 64.48, 73.27, 53.85, 90.06, 84.97, 70.73, 71.69, 79.04, 52.94, 89.15, 75.99, 55.37, 63.15, 83.28, 80.06, 71.48, 61.04, 50.23, 52.23, 82.6, 56.4, 69.68, 85.7, 73.91, 56.04, 48.41, 62.18, 54.03, 77.94, 71.01, 56.48, 75.83, 67.13, 75.68, 53.65, 88.11, 92.16, 50.37]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción fabrica 1')

ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Produccion fabrica 2')

plt.show()

# %%
# Sera un valor atípico
fabrica1.append(150)
print(fabrica1)
# Out:
# [86.77, 88.23, 98.31, 85.25, 73.56, 86.4, 64.13, 59.17, 91.49, 83.34, 88.53, 52.93, 89.33, 97.35, 85.16, 99.75, 85.82, 54.35, 54.93, 84.75, 91.5, 89.08, 64.66, 85.39, 70.29, 76.47, 71.51, 79.58, 70.17, 78.92, 50.56, 84.76, 64.88, 89.37, 70.96, 64.13, 62.87, 99.07, 83.27, 89.63, 60.34, 89.01, 94.2, 50.39, 78.46, 98.68, 61.03, 95.52, 64.99, 63.18, 65.51, 86.43, 69.5, 93.16, 73.81, 80.51, 81.85, 50.46, 50.04, 58.78, 74.99, 60.39, 75.85, 78.97, 65.07, 68.14, 99.78, 99.06, 58.56, 64.01, 56.94, 83.94, 63.77, 64.95, 82.24, 77.12, 73.47, 68.77, 53.82, 61.87, 61.66, 82.74, 53.8, 92.22, 77.14, 84.43, 60.3, 98.35, 65.14, 86.94, 87.24, 77.06, 61.33, 66.42, 93.36, 86.18, 75.11, 68.67, 84.41, 61.74, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción fabrica 1')

ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Producción fabrica 2')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 5))

ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción fabrica 1')
ax1.set_ylim(30, 160)

ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Producción fabrica 2')
ax2.set_ylim(30, 160)

plt.show()
