# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Unidad1/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##UNIDAD 1
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
# ###Alumno: FUENTES GONZÁLEZ KARLA MARÍA
# PROGRAMA 4: **Diagramas de cajas y bigotes**

# %%
import random

import matplotlib.pyplot as plt

from statistics import *

# %%
fabrica1 = []

for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)

print(fabrica1)
# Out:
# [96.05, 83.67, 82.52, 99.09, 64.52, 65.77, 55.87, 98.08, 69.23, 54.9, 95.26, 78.1, 91.32, 89.33, 61.5, 60.37, 85.04, 78.36, 83.47, 77.12, 69.99, 83.02, 69.45, 65.74, 66.55, 56.93, 88.04, 50.18, 54.67, 54.03, 76.16, 90.5, 99.16, 84.77, 69.28, 98.73, 94.91, 87.44, 79.11, 68.89, 55.75, 89.82, 85.21, 70.6, 93.61, 96.38, 60.1, 80.74, 62.85, 93.45, 91.26, 87.08, 56.12, 92.56, 57.9, 78.21, 55.12, 85.39, 89.4, 95.07, 93.96, 73.17, 51.87, 73.13, 67.28, 58.32, 65.17, 86.39, 81.29, 52.76, 86.07, 68.97, 50.22, 83.95, 72.24, 78.23, 56.21, 95.8, 70.58, 93.21, 57.98, 55.2, 92.6, 57.41, 86.84, 98.43, 99.03, 92.5, 53.94, 96.96, 92.02, 53.25, 86.67, 60.84, 74.56, 87.44, 72.86, 86.06, 76.6, 58.86]

# %%
fabrica2 = []

for i in range(100):
    numero_aleatorio = round(random.uniform(48, 93), 2)
    fabrica2.append(numero_aleatorio)

print(fabrica2)
# Out:
# [73.83, 80.93, 52.72, 83.66, 68.78, 89.37, 59.08, 50.27, 87.58, 50.2, 74.72, 65.23, 68.71, 63.45, 84.12, 67.57, 55.15, 51.28, 79.85, 55.26, 92.8, 78.27, 90.22, 55.04, 75.16, 71.57, 87.82, 73.55, 48.97, 87.48, 88.53, 64.27, 67.34, 77.3, 48.69, 59.72, 86.5, 69.21, 62.42, 72.83, 81.23, 61.64, 61.23, 60.87, 69.13, 87.11, 84.35, 91.32, 90.06, 91.38, 58.99, 76.97, 88.28, 79.28, 60.11, 58.58, 71.69, 61.53, 86.37, 87.22, 60.87, 85.08, 49.43, 84.92, 87.71, 64.79, 70.64, 82.45, 80.13, 51.47, 86.63, 78.11, 51.75, 62.06, 77.47, 67.94, 73.77, 52.24, 81.77, 53.23, 53.69, 75.55, 80.29, 57.47, 75.74, 51.98, 53.75, 77.31, 76.26, 67.94, 69.81, 57.59, 65.21, 66.32, 85.35, 55.12, 86.16, 59.37, 49.54, 79.3]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción fabrica 1')

ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Produccion fabrica 2')

plt.show()

# %%
# Sera un valor atípico
fabrica1.append(150)
print(fabrica1)
# Out:
# [96.05, 83.67, 82.52, 99.09, 64.52, 65.77, 55.87, 98.08, 69.23, 54.9, 95.26, 78.1, 91.32, 89.33, 61.5, 60.37, 85.04, 78.36, 83.47, 77.12, 69.99, 83.02, 69.45, 65.74, 66.55, 56.93, 88.04, 50.18, 54.67, 54.03, 76.16, 90.5, 99.16, 84.77, 69.28, 98.73, 94.91, 87.44, 79.11, 68.89, 55.75, 89.82, 85.21, 70.6, 93.61, 96.38, 60.1, 80.74, 62.85, 93.45, 91.26, 87.08, 56.12, 92.56, 57.9, 78.21, 55.12, 85.39, 89.4, 95.07, 93.96, 73.17, 51.87, 73.13, 67.28, 58.32, 65.17, 86.39, 81.29, 52.76, 86.07, 68.97, 50.22, 83.95, 72.24, 78.23, 56.21, 95.8, 70.58, 93.21, 57.98, 55.2, 92.6, 57.41, 86.84, 98.43, 99.03, 92.5, 53.94, 96.96, 92.02, 53.25, 86.67, 60.84, 74.56, 87.44, 72.86, 86.06, 76.6, 58.86, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción fabrica 1')

ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Producción fabrica 2')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 5))

ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción fabrica 1')
ax1.set_ylim(30, 160)

ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Producción fabrica 2')
ax2.set_ylim(30, 160)

plt.show()
