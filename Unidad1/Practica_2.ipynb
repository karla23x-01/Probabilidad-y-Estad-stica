# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Unidad1/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##UNIDAD 1
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
# ###Alumno: FUENTES GONZÁLEZ KARLA MARÍA
# PROGRAMA 2: **MAXIMO, MINIMO Y DISPERSION DE DATOS**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
Fabrica1 = []
for _ in range (100):
    numero_aleatorio=round(random.uniform(50,1000), 2)
    Fabrica1.append(numero_aleatorio)
print(Fabrica1)
# Out:
# [566.48, 629.85, 183.69, 413.52, 609.7, 249.67, 148.99, 409.35, 931.05, 767.16, 892.38, 699.27, 733.82, 585.85, 688.32, 589.33, 639.61, 406.38, 594.9, 911.1, 791.94, 148.68, 271.83, 103.77, 502.77, 447.18, 878.44, 438.05, 88.25, 775.39, 63.3, 214.47, 459.7, 663.46, 204.53, 202.28, 770.47, 844.97, 330.49, 387.45, 469.33, 951.87, 426.18, 635.44, 803.27, 662.55, 293.05, 739.19, 847.04, 347.11, 336.57, 982.71, 463.81, 412.43, 784.09, 193.88, 179.74, 126.2, 135.99, 545.46, 714.96, 827.28, 345.29, 911.52, 399.62, 974.03, 934.39, 426.85, 845.84, 389.72, 611.91, 697.42, 456.29, 306.64, 551.22, 210.34, 855.97, 659.92, 444.11, 317.47, 228.45, 781.89, 209.29, 971.79, 459.71, 134.33, 138.55, 419.41, 393.1, 611.26, 202.21, 127.04, 963.94, 248.95, 146.11, 648.83, 787.56, 387.64, 273.04, 962.55]

# %%
Fabrica2 = []
for _ in range(100):
   numero_aleatorio=round (random.uniform(50,1000), 2)
   Fabrica2.append(numero_aleatorio)
print(Fabrica2)
# Out:
# [743.65, 623.3, 609.49, 413.68, 96.63, 932.91, 412.12, 212.59, 340.16, 465.82, 676.24, 453.04, 913.01, 369.29, 913.88, 119.6, 690.03, 783.01, 909.34, 692.93, 382.81, 675.42, 115.79, 170.87, 389.7, 810.65, 905.12, 148.05, 284.9, 190.23, 106.06, 841.65, 568.86, 489.79, 188.37, 824.03, 205.12, 408.82, 501.93, 918.42, 62.81, 597.63, 541.92, 229.96, 201.84, 467.24, 559.07, 250.32, 842.67, 926.21, 729.75, 183.06, 340.82, 478.98, 312.38, 313.09, 387.2, 150.5, 139.26, 199.17, 856.51, 382.19, 658.93, 376.68, 206.63, 544.71, 179.26, 923.1, 818.55, 972.89, 304.6, 376.81, 896.83, 481.11, 930.89, 118.49, 671.24, 177.51, 719.94, 613.02, 576.22, 100.55, 347.34, 929.62, 85.45, 274.86, 879.58, 446.0, 327.02, 184.37, 424.19, 801.78, 812.91, 708.47, 937.65, 131.91, 132.03, 844.78, 391.31, 577.58]

# %%
maximo1 = max(Fabrica1)
minimo1 = min (Fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(Fabrica1)
mediana1 = median(Fabrica1)
moda1 = mode(Fabrica1)
desviacion_estandar_Fabrica1 = stdev(Fabrica1)
print("Estadistica descriptiva de la Fabrica 1 \n", "Media =",media1,"\n Mediana =", mediana1, "\n Moda=",moda1, "\n Maximo=",maximo1,"\n Minimo =", minimo1, "\n Rango=", rango1)
print("Desviacion Estandar =", desviacion_estandar_Fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 515.5019
#  Mediana = 461.76
#  Moda= 566.48
#  Maximo= 982.71
#  Minimo = 63.3
#  Rango= 919.4100000000001
# Desviacion Estandar = 266.8884974102273

# %%
plt.figure(figsize = (8,6) )
plt.hist(Fabrica1, bins=10, alpha=0.2, color= 'b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_Fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desy. Estándar ={desviacion_estandar_Fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_Fabrica1, color='black', linestyle= 'dashed',linewidth=2)
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend ()
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(x=Fabrica1,kde=True,kde_kws={'bw_adjust':0.5},bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
maximo2 = max(Fabrica2)
minimo2 = min (Fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(Fabrica2)
mediana2 = median(Fabrica2)
moda2 = mode(Fabrica2)
desviacion_estandar_Fabrica2 = stdev(Fabrica2)
print("Estadistica descriptiva de la Fabrica 2 \n", "Media =",media2,"\n Mediana =", mediana2, "\n Moda=",moda2, "\n Maximo=",maximo2,"\n Minimo =", minimo2, "\n Rango=", rango2)
print("Desviacion Estandar =",desviacion_estandar_Fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 495.347
#  Mediana = 459.43
#  Moda= 743.65
#  Maximo= 972.89
#  Minimo = 62.81
#  Rango= 910.0799999999999
# Desviacion Estandar = 278.2227565342838

# %%
plt.figure(figsize = (8,6) )
plt.hist(Fabrica2, bins=10, alpha=0.2, color= 'b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media2 - desviacion_estandar_Fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desy. Estándar ={desviacion_estandar_Fabrica1:.2f}')
plt.axvline(media2 + desviacion_estandar_Fabrica2, color='black', linestyle= 'dashed',linewidth=2)
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend ()
plt.show()

# %%
sns.histplot(x=Fabrica2,kde=True,kde_kws={'bw_adjust':0.5},bins=10)
# Out:
# <Axes: ylabel='Count'>
