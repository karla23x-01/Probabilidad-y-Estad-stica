# %% [markdown]
# <a href="https://colab.research.google.com/github/karla23x-01/Probabilidad-y-Estad-stica/blob/main/Unidad3/Practica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadística
# ##Unidad 3
# ###Facilitador: José Gabriel Rodriguez Rivas
# ###Alumno: Karla María Fuentes González
# ### **Programa 5: Gráfica de distribución de probabilidad discreta**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,6,7,8,9,10])
p=np.array([0.05,0.10,0.20,0.30,0.25,0.10])
esperanza = np.sum(x*p)
esperanza_cuadrado = np.sum(x**2*p)
varianza = esperanza_cuadrado - esperanza**2
desviacion = np.sqrt(varianza)

print(f"E(x)= {esperanza:.2f}")
print(f"E(x2) = {esperanza_cuadrado:.2f}")
print(f"varianza = {varianza:.2f}")
print(f"desviacion estandar = {desviacion:.2f}")

plt.stem(x,p, basefmt=" ", linefmt= "b-", markerfmt="bo")
plt.title("distribucion de probabilidad discreta\ncon Media y desviacion estandar")
plt.xlabel("p(x)")
plt.grid(True, linestyle= "--", alpha=0.6)
plt.axvline(x=esperanza, color="red", linestyle="--", label=f"Media (E[x])={esperanza:.2f}")
plt.axvspan(esperanza-desviacion, esperanza + desviacion, color="red", alpha=0.2,label=f"+-1 desv. estandar(o= {desviacion:.2f})")

plt.legend()
plt.ylim(0,max(p) + 0.05)
plt.xticks(x)
plt.show()
# Out:
# E(x)= 7.90
# E(x2) = 64.10
# varianza = 1.69
# desviacion estandar = 1.30
